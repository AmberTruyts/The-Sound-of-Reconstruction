# %% [markdown]
# # Data exploration: Productions and Composers

# %% [markdown]
# Using the merged dataset (complete_dataset) containing all of the collected data over the period of 1893-1963 by Mona Allaert, Elisabeth Jansen and me to explore productions and composers.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('complete_dataset.csv', encoding='utf-8', index_col=False)
# Removing redundant columns
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
df.sample(10)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#                                                    Image Collection  \
# 10652                      Scan 2024-04-29 1742-179.jpeg  1962-1963
# 3804                 1930-1931_00408-20220209_164137.jpg  1930-1931
# 5006                 1937-1938_00142-20230218_163652.jpg  1937-1938
# 9894                       Scan 2024-03-25 1453-181.jpeg  1959-1960
# 9693                        Scan 2024-03-18 1621-86.jpeg  1957-1958
# 581    1901-1902 Nederlandsch Lyrisch Tooneel Program...  1901-1902
# 8808                       Scan 2024-03-11 1427-106.jpeg  1954-1955
# 852    1904-1905 Nederlands Lyrisch Tooneel programma...  1904-1905
# 4576                 1934-1935_00248-20230218_132432.jpg  1934-1935
# 927    Nederlandsch Lyrisch Tooneel 1905-1906_00206-2...  1905-1906
#
#                     Production        Date  \
# 10652   Een Midzomernachtdroom         NaN
# 3804                 Lohengrin  1931-01-06
# 5006                    Paljas  1938-01-06
# 9894                 Rigoletto         NaN
# 9693                  Pierlala         NaN
# 581    De Vrouwkens van Brugge  1902-03-08
# 8808      Iphigeneia in Tauris         NaN
# 852          Winternachtsdroom  1905-09-02
# 4576          Madame Sans-Gêne  1935-03-10
# 927           De Bruid der Zee  1906-03-17
#
#                                                 Occasion  Multiple Bill  \
# 10652                                                NaN          False
# 3804                                                gala          False
# 5006                                                 NaN           True
# 9894                                                 NaN          False
# 9693                                                 NaN           True
# 581    Ten voordele der slachtoffers der folterkampen...          False
# 8808                                                 NaN          False
# 852                                       Volksvertoning          False
# 4576                                                 NaN          False
# 927                                                  NaN          False
#
#        Performance_ID         Normalized Title Original Language  \
# 10652          866721   Een Midzomernachtdroom               NaN
# 3804           590169                Lohengrin               DUI
# 5006           710207                   Paljas               ITA
# 9894           450460                Rigoletto               ITA
# 9693           825263                 Pierlala                NL
# 581            114200  De Vrouwkens van Brugge                NL
# 8808           340313     Iphigeneia in Tauris                FR
# 852            550659        Winternachtsdroom                NL
# 4576           452110         Madame Sans-Gêne               ITA
# 927            104970         De Bruid der Zee                NL
#
#                         Composer Original Premiere           Original Title  \
# 10652                        NaN               NaN                      NaN
# 3804              Richard Wagner              1850                Lohengrin
# 5006        Ruggiero Leoncavallo              1892                Pagliacci
# 9894              Giuseppe Verdi               NaN                Rigoletto
# 9693           Daniel Sternefeld               NaN                 Pierlala
# 581                     E. Britt                 ?  De Vrouwkens van Brugge
# 8808   Christoph Willibald Gluck              1774      Iphigénie en Aulide
# 852              August de Boeck              1902        Winternachtsdroom
# 4576            Umberto Giordano              1915         Madame Sans-Gêne
# 927                   Jan Blockx              1901         De Bruid der Zee
#
#                    Genre     Season                    Directors  \
# 10652                NaN  1962-1963            Renaat Verbruggen
# 3804    romantische oper  1930-1931  Fé Derickx & Bernard Tokkie
# 5006             verisme  1937-1938                 Jef Sterkens
# 9894           melodrama  1959-1960                Mina Bolotine
# 9693            zangspel  1957-1958               August Baeyens
# 581                    ?  1901-1902              Karel van Walle
# 8808               opera  1954-1955               August Baeyens
# 852        lyrisch drama  1905-1906  Jef Judels & Bernard Tokkie
# 4576    lyrische komedie  1934-1935                 Flor Bosmans
# 927    romantische opera  1905-1906  Jef Judels & Bernard Tokkie
#
#       Title Language Leaflet Language
# 10652            NaN              ned
# 3804             Unk              NaN
# 5006             Unk            Dutch
# 9894             Unk              ned
# 9693             Unk              ned
# 581               NL              NaN
# 8808              NL              ned
# 852               NL              NaN
# 4576             Unk            Dutch
# 927               NL              NaN

# %%
# Split the dataset into separate dataframes for pre-, during, and post-war

# Period after WWI and before WWII
df1919_1939 = df[(df['Season'] >= '1918-1919') & (df['Season'] <= '1939-1940')]

# During WWII (season 1944/1945 ends on the 31st of July 1945, two months before the end of the war)
df1940_1945 = df[(df['Season'] >= '1940-1941') & (df['Season'] <= '1944-1945')]

# After WWII
df1946_1963 = df[(df['Season'] >= '1945-1946') & (df['Season'] <= '1962-1963')]

# %% [markdown]
# ## Top 10 productions

# %%
# First let's look at the full dataset 1893-1963

df['Normalized Title'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'blue')
plt.title("Top 10 Most Frequent Productions 1893-1963");

# %%
# Between WWI and WWII

df1919_1939['Normalized Title'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'blue')
plt.title("Top 10 Most Frequent Productions 1919-1939");

# %%
# During WWII

df1940_1945['Normalized Title'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'blue')
plt.title("Top 10 Most Frequent Productions 1940-1945");

# %%
# After WWII

df1946_1963['Normalized Title'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'blue')
plt.title("Top 10 Most Frequent Productions 1946-1963");

# %% [markdown]
# ## Top 10 composers

# %%
# Full dataset

df['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'green')
plt.title("Top 10 Most Frequent Composers 1893-1963");

# %%
# Between WWI and WWII

df1919_1939['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'green')
plt.title("Top 10 Most Frequent Composers 1919-1939");

# %%
# During WWII

df1940_1945['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'green')
plt.title("Top 10 Most Frequent Composers 1940-1945");

# %%
# After WWII

df1946_1963['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'green')
plt.title("Top 10 Most Frequent Composers 1946-1963");

# %% [markdown]
# ## Top 10 Dutch Composers

# %%
# Full dataset

# Isolate all Dutch productions
df_nl = df[df["Original Language"] == 'NL']

df_nl['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'red')
plt.title("Top 10 Most Frequent Dutch Composers 1893-1963");

# %%
# Between WWI and WWII

df_nl_1919_1939 = df1919_1939[df1919_1939["Original Language"] == 'NL']
df_nl_1919_1939['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'red')
plt.title("Top 10 Most Frequent Dutch Composers 1919-1939");

# %%
# During WWII

df_nl_1940_1945 = df1940_1945[df1940_1945["Original Language"] == 'NL']
df_nl_1940_1945['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'red')
plt.title("Top 10 Most Frequent Dutch Composers 1940-1945");

# %%
# After WWII

df_nl_1946_1963 = df1946_1963[df1946_1963["Original Language"] == 'NL']
df_nl_1946_1963['Composer'].value_counts(normalize=True).head(10).plot(kind='bar', color = 'red')
plt.title("Top 10 Most Frequent Dutch Composers 1946-1963");

# %%
# Top productions of the top 10 composers 1946-1963

# Relative frequency of composers 1946-1963
comp_seasons = df1946_1963['Composer'].value_counts(normalize=True).head(10)

# Display the relative frequency for each composer
print("Relative Frequency of Top 10 Composers in Seasons 1946-1963:")
print(comp_seasons)

# Display the normalized titles for each composer in the top 10 with percentage for the entire period 1946-1963
top_composers_seasons = comp_seasons.index.tolist()

# Calculate the total performances for the entire period 1946-1963
total_performances_all = df1946_1963.shape[0]

for composer in top_composers_seasons:
    composer_df = df1946_1963[df1946_1963['Composer'] == composer]
    titles_count = composer_df.groupby('Normalized Title').size().reset_index(name='Count')
    titles_count['Percentage'] = (titles_count['Count'] / total_performances_all) * 100
    print(f"\nTop Productions for {composer} in Seasons 1946-1963:")
    print(titles_count)
# Out:
# Relative Frequency of Top 10 Composers in Seasons 1946-1963:
# Giacomo Puccini            0.089346
# Giuseppe Verdi             0.074092
# Richard Wagner             0.064649
# Franz Lehár                0.050605
# Georges Bizet              0.038257
# Wolfgang Amadeus Mozart    0.037530
# Charles Gounod             0.032203
# Pietro Mascagni            0.025182
# August Baeyens             0.024939
# Ruggiero Leoncavallo       0.023245
# Name: Composer, dtype: float64
#
# Top Productions for Giacomo Puccini in Seasons 1946-1963:
#              Normalized Title  Count  Percentage
# 0                      Bohème    117    2.733645
# 1             Gianni Schicchi     18    0.420561
# 2  Het Meisje uit de Far-West      4    0.093458
# 3            Madame Butterfly    112    2.616822
# 4               Manon Lescaut     11    0.257009
# 5                       Tosca     85    1.985981
# 6                    Turandot     17    0.397196
# 7             Zuster Angelica      5    0.116822
#
# Top Productions for Giuseppe Verdi in Seasons 1946-1963:
#            Normalized Title  Count  Percentage
# 0                      Aïda     54    1.261682
# 1  De Macht van het Noodlot     10    0.233645
# 2             De Troubadour     25    0.584112
# 3                Don Carlos     18    0.420561
# 4         Het Gemaskerd Bal     12    0.280374
# 5                 Rigoletto     72    1.682243
# 6                  Traviata    115    2.686916
#
# Top Productions for Richard Wagner in Seasons 1946-1963:
#                    Normalized Title  Count  Percentage
# 0   De Meesterzangers van Nurenberg     10    0.233645
# 1            De Vliegende Hollander     30    0.700935
# 2                        De Walkure     26    0.607477
# 3                  Godendeemstering      2    0.046729
# 4                   Godenschemering      3    0.070093
# 5                      Het Rijngoud     23    0.537383
# 6                         Lohengrin     51    1.191589
# 7                          Parsifal     41    0.957944
# 8                         Siegfried      5    0.116822
# 9                        Tannhauser     64    1.495327
# 10                Tristan en Isolde     12    0.280374
#
# Top Productions for Franz Lehár in Seasons 1946-1963:
#             Normalized Title  Count  Percentage
# 0     De Graaf van Luxemburg     30    0.700935
# 1          De Lustige Weduwe     54    1.261682
# 2             De Tsarewitsch     11    0.257009
# 3                  Frederika     16    0.373832
# 4  Het Land van den Glimlach     93    2.172897
# 5                   Paganini      5    0.116822
#
# Top Productions for Georges Bizet in Seasons 1946-1963:
#     Normalized Title  Count  Percentage
# 0             Carmen    123    2.873832
# 1  De Parelvisschers     35    0.817757
#
# Top Productions for Wolfgang Amadeus Mozart in Seasons 1946-1963:
#                Normalized Title  Count  Percentage
# 0                  Ballet-suite     18    0.420561
# 1                Cosi fan Tutte      5    0.116822
# 2  De Ontvoering uit het Serail     20    0.467290
# 3                  Don Giovanni     33    0.771028
# 4        Een Kleine Nachtmuziek     10    0.233645
# 5             Figaro's Bruiloft     16    0.373832
# 6                      Idomeneo      7    0.163551
# 7                   Tooverfluit     46    1.074766
#
# Top Productions for Charles Gounod in Seasons 1946-1963:
#   Normalized Title  Count  Percentage
# 0            Faust    133    3.107477
#
# Top Productions for Pietro Mascagni in Seasons 1946-1963:
#        Normalized Title  Count  Percentage
# 0  Cavalleria Rusticana     98    2.289720
# 1                  Iris      6    0.140187
#
# Top Productions for August Baeyens in Seasons 1946-1963:
#    Normalized Title  Count  Percentage
# 0  Zwarte Viooltjes    103    2.406542
#
# Top Productions for Ruggiero Leoncavallo in Seasons 1946-1963:
#   Normalized Title  Count  Percentage
# 0           Paljas     96    2.242991

# %% [markdown]
# ## Distribution of German productions and Wagner

# %%
# Creating subdataset with all Wagner performances 1893-1963

wag = df[df['Composer'] == 'Richard Wagner']
ger = df[df['Original Language'] == 'DUI']

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Creating 2 series: one for all German performances and one for only the wagner performances
counts1 = ger['Season'].value_counts().sort_index(axis=0)
counts2 = wag['Season'].value_counts().sort_index(axis=0)

# Sorting the index so that the seasons occur chronologically on the plot
counts2 = counts2.sort_index()
counts1 = counts1.sort_index()

# Generating x and y data for the line plot, otherwise it doesn't plot all the index labels
x = counts1.index
y = counts1.values

x2 = counts2.index
y2 = counts2.values

ax.plot(x, y, color='lightseagreen', label='German')
ax.plot(x2, y2, color = 'orange', label = 'Wagner')

ax.set_xticks(range(len(x)))
ax.set_xticklabels(x, rotation=-90)

ax.set_xlabel('Season')
ax.set_ylabel('Count')
ax.legend()
ax.set_title('Distibution of Wagner and German performances 1893-1963')

plt.show()

# %%
# Now a subdataset with German and Wagner performances 1946-1963

wag = df1946_1963[df1946_1963['Composer'] == 'Richard Wagner']
ger = df1946_1963[df1946_1963['Original Language'] == 'DUI']

# %%
fig, ax = plt.subplots(figsize=(12, 6))

counts1 = ger['Season'].value_counts().sort_index(axis=0)
counts2 = wag['Season'].value_counts().sort_index(axis=0)

counts2 = counts2.sort_index()
counts1 = counts1.sort_index()

x = counts1.index
y = counts1.values

x2 = counts2.index
y2 = counts2.values

ax.plot(x, y, color='lightseagreen', label='German')
ax.plot(x2, y2, color = 'orange', label = 'Wagner')

ax.set_xticks(range(len(x)))
ax.set_xticklabels(x, rotation=-90)

ax.set_xlabel('Season')
ax.set_ylabel('Count')
ax.legend()
ax.set_title('Distribution of Wagner and German performances 1946-1963')

plt.show()
